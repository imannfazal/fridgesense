# %%
import pandas as pd
#takes raw text and converts into format that langchain can understand
from langchain_community.document_loaders import TextLoader
#split the document into meaningful chunks
from langchain_text_splitters import CharacterTextSplitter
#converting chunks into document embeddings
from langchain_openai import OpenAIEmbeddings
#vectorDB to store embeddings
from langchain_chroma import Chroma

# %%
recipes = pd.read_csv("final_recipes_data.csv")

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
recipes.columns
# Out:
# Index(['id', 'name', 'ingredients', 'steps', 'servings', 'ingredients_cleaned',
#        'tags_merged'],
#       dtype='object')

# %%
import ast

def safe_eval(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except (ValueError, SyntaxError):
            # try to "fix" some broken escape chars
            x = x.replace('\\"', '"').replace("\\'", "'").replace("\\", "")
            try:
                return ast.literal_eval(x)
            except Exception:
                return [x]  # fallback: wrap raw string in list
    return x

recipes["ingredients"] = recipes["ingredients"].apply(safe_eval)

# %%
import ast

def safe_literal_eval(x):
    if isinstance(x, str):  # only try if it's a string
        try:
            return ast.literal_eval(x)
        except (ValueError, SyntaxError):
            return x  # if still broken, return as-is
    return x  # already list (or other type)

recipes["ingredients"] = recipes["ingredients"].apply(safe_literal_eval)
recipes["ingredients_cleaned"] = recipes["ingredients_cleaned"].apply(safe_literal_eval)
recipes["steps"] = recipes["steps"].apply(safe_literal_eval)
recipes["tags_merged"] = recipes["tags_merged"].apply(
    lambda x: [tag.strip() for tag in x.split(",")] if isinstance(x, str) else x
)

# %%
recipes["tags_merged"].dtype
# Out:
# dtype('O')

# %%
recipes["embedding_text"] = recipes.apply(
    lambda row: (
        f"ID: {row['id']} | "
        f"Name: {row['name']} | "
        f"Ingredients: {' | '.join(row['ingredients']) if isinstance(row['ingredients'], list) else row['ingredients']} | "
        f"Tags: {' | '.join(row['tags_merged']) if isinstance(row['tags_merged'], list) else row['tags_merged']} | "
        f"Servings: {int(row['servings'])}"
    ),
    axis=1
)

# %%
recipes["embedding_text"].to_csv("embedding_text.txt", index=False, header=False, sep='\n')

# %%
recipes["embedding_text"]
# Out:
# 0         ID: 71247 | Name: Cherry Streusel Cobbler | In...
# 1         ID: 76133 | Name: Reuben and Swiss Casserole B...
# 2         ID: 503816 | Name: Yam-Pecan Recipe | Ingredie...
# 3         ID: 418749 | Name: Tropical  Orange Layer Cake...
# 4         ID: 392934 | Name: Safe to Eat Raw Chocolate C...
#                                 ...
# 491588    ID: 173790 | Name: Sausage Meatloaf OAMC | Ing...
# 491589    ID: 301838 | Name: Potato Salad With Olives Ca...
# 491590    ID: 130682 | Name: Chocolate Banana Pound Cake...
# 491591    ID: 353659 | Name: Cheesy Ground Beef and Rice...
# 491592    ID: 510848 | Name: Chicken and Dumplings &ndas...
# Name: embedding_text, Length: 491593, dtype: object

# %%
from langchain.schema import Document

# load file directly
with open("embedding_text.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# convert each line into a Document
documents = [
    Document(page_content=line.strip())
    for line in lines if line.strip()
]

print(f"Created {len(documents)} documents")
print("Example:", documents[0].page_content[:200])
# Out:
# Created 491593 documents
# Example: ID: 71247 | Name: Cherry Streusel Cobbler | Ingredients: cherry pie filling | condensed milk | melted margarine | cinnamon | nutmeg | light brown sugar | flour | margarine | chopped nuts | oats | butt

# %%
from langchain.text_splitter import CharacterTextSplitter

raw = TextLoader("embedding_text.txt", encoding="utf-8").load()
text_splitter = CharacterTextSplitter(
    chunk_size=1000,  # instead of 1
    chunk_overlap=0,
    separator="\n"
)
documents = text_splitter.split_documents(raw)
print(len(documents))  # should be ~10–20k instead of 491k
# Out:
# Created a chunk of size 1033, which is longer than the specified 1000
# Created a chunk of size 1044, which is longer than the specified 1000
# Created a chunk of size 1097, which is longer than the specified 1000
# Created a chunk of size 1003, which is longer than the specified 1000
# Created a chunk of size 1118, which is longer than the specified 1000
# Created a chunk of size 1113, which is longer than the specified 1000
# Created a chunk of size 1025, which is longer than the specified 1000
# Created a chunk of size 1010, which is longer than the specified 1000
# Created a chunk of size 1009, which is longer than the specified 1000
# Created a chunk of size 1008, which is longer than the specified 1000
# Created a chunk of size 1111, which is longer than the specified 1000
# Created a chunk of size 1121, which is longer than the specified 1000
# Created a chunk of size 1017, which is longer than the specified 1000
# 212716

# %%
from langchain_core.documents import Document
import re

new_documents = []

for doc in documents:
    # Split by newline followed by ID:
    recipes = re.split(r'\n(?=ID:)', doc.page_content)
    for recipe in recipes:
        new_documents.append(Document(page_content=recipe, metadata=doc.metadata))

print(len(new_documents))
print(new_documents[1].page_content)
print(new_documents[2].page_content)  # preview first recipe
# Out:
# 491407
# ID: 76133 | Name: Reuben and Swiss Casserole Bake | Ingredients: corned beef chopped | sauerkraut cold water | swiss cheese shredded | rye bread | butter | Tags: 60-minutes-or-less | casseroles | cheese | eggs-dairy | main-dish | oven | Servings: 4
# ID: 503816 | Name: Yam-Pecan Recipe | Ingredients: unsalted butter | vegetable oil | all - purpose flour | baking soda | chopped pecans | mashed canned louisiana yams juice glaze | unsalted butter | juice yam | Tags: 3-steps-or-less | 4-hours-or-less | american | breads | cajun | comfort-food | easy | gifts | holiday-event | north-american | nuts | quick-breads | southern-united-states | Servings: 8

# %%
print(new_documents[0].page_content)
print(new_documents[1].page_content)
print(new_documents[2].page_content)
# Out:
# ID: 71247 | Name: Cherry Streusel Cobbler | Ingredients: cherry pie filling | condensed milk | melted margarine | cinnamon | nutmeg | light brown sugar | flour | margarine | chopped nuts | oats | butter - flavored cooking spray | Tags: 60-minutes-or-less | cherries | cobblers-and-crisps | desserts | fruit | north-american | oven | pitted-fruit | Servings: 6
# ID: 76133 | Name: Reuben and Swiss Casserole Bake | Ingredients: corned beef chopped | sauerkraut cold water | swiss cheese shredded | rye bread | butter | Tags: 60-minutes-or-less | casseroles | cheese | eggs-dairy | main-dish | oven | Servings: 4
# ID: 503816 | Name: Yam-Pecan Recipe | Ingredients: unsalted butter | vegetable oil | all - purpose flour | baking soda | chopped pecans | mashed canned louisiana yams juice glaze | unsalted butter | juice yam | Tags: 3-steps-or-less | 4-hours-or-less | american | breads | cajun | comfort-food | easy | gifts | holiday-event | north-american | nuts | quick-breads | southern-united-states | Servings: 8

# %%
import pickle

with open("all_recipes.pkl", "wb") as f:
    pickle.dump(new_documents, f)

# %%
import voyageai
import time
import os

# 1️⃣ Load your recipes from text file
with open("embedding_text.txt", "r", encoding="utf-8") as f:
    recipes = [line.strip() for line in f if line.strip()]

print(f"Loaded {len(recipes)} recipes for embedding.")

# 2️⃣ Initialize Voyage client
vo = voyageai.Client()  # make sure VOYAGE_API_KEY is set

# 3️⃣ Parameters
batch_size = 100            # safe batch size under free limits
output_dir = "embeddings_batches"
os.makedirs(output_dir, exist_ok=True)

# 4️⃣ Embed in batches and save each batch to disk
for i in range(0, len(recipes), batch_size):
    batch = recipes[i:i + batch_size]
    try:
        result = vo.embed(batch, model="voyage-3.5", input_type="document")
        
        # Save this batch to disk
        batch_filename = os.path.join(output_dir, f"embeddings_{i}_{i+len(batch)}.pkl")
        with open(batch_filename, "wb") as f:
            import pickle
            pickle.dump(result.embeddings, f)
        
        print(f"✅ Batch {i} → {i + len(batch)} done, saved to {batch_filename}")
        
        time.sleep(1)  # small pause to avoid rate limits
    except Exception as e:
        print(f"❌ Error at batch {i} → {i + len(batch)}: {e}")
        time.sleep(5)

print("✅ Finished embedding all recipes.")
# Out:
# Loaded 491593 recipes for embedding.
# ✅ Batch 0 → 100 done, saved to embeddings_batches\embeddings_0_100.pkl
# ✅ Batch 100 → 200 done, saved to embeddings_batches\embeddings_100_200.pkl
# ✅ Batch 200 → 300 done, saved to embeddings_batches\embeddings_200_300.pkl
# ✅ Batch 300 → 400 done, saved to embeddings_batches\embeddings_300_400.pkl
# ✅ Batch 400 → 500 done, saved to embeddings_batches\embeddings_400_500.pkl
# ✅ Batch 500 → 600 done, saved to embeddings_batches\embeddings_500_600.pkl
# ✅ Batch 600 → 700 done, saved to embeddings_batches\embeddings_600_700.pkl
# ✅ Batch 700 → 800 done, saved to embeddings_batches\embeddings_700_800.pkl
# ✅ Batch 800 → 900 done, saved to embeddings_batches\embeddings_800_900.pkl
# ✅ Batch 900 → 1000 done, saved to embeddings_batches\embeddings_900_1000.pkl
# ✅ Batch 1000 → 1100 done, saved to embeddings_batches\embeddings_1000_1100.pkl
# ✅ Batch 1100 → 1200 done, saved to embeddings_batches\embeddings_1100_1200.pkl
# ✅ Batch 1200 → 1300 done, saved to embeddings_batches\embeddings_1200_1300.pkl
# ✅ Batch 1300 → 1400 done, saved to embeddings_batches\embeddings_1300_1400.pkl
# ✅ Batch 1400 → 1500 done, saved to embeddings_batches\embeddings_1400_1500.pkl
# ✅ Batch 1500 → 1600 done, saved to embeddings_batches\embeddings_1500_1600.pkl
# ✅ Batch 1600 → 1700 done, saved to embeddings_batches\embeddings_1600_1700.pkl
# ✅ Batch 1700 → 1800 done, saved to embeddings_batches\embeddings_1700_1800.pkl
# ✅ Batch 1800 → 1900 done, saved to embeddings_batches\embeddings_1800_1900.pkl
# ✅ Batch 1900 → 2000 done, saved to embeddings_batches\embeddings_1900_2000.pkl
# ✅ Batch 2000 → 2100 done, saved to embeddings_batches\embeddings_2000_2100.pkl
# ✅ Batch 2100 → 2200 done, saved to embeddings_batches\embeddings_2100_2200.pkl
# ✅ Batch 2200 → 2300 done, saved to embeddings_batches\embeddings_2200_2300.pkl
# ✅ Batch 2300 → 2400 done, saved to embeddings_batches\embeddings_2300_2400.pkl
# ✅ Batch 2400 → 2500 done, saved to embeddings_batches\embeddings_2400_2500.pkl
# ✅ Batch 2500 → 2600 done, saved to embeddings_batches\embeddings_2500_2600.pkl
# ✅ Batch 2600 → 2700 done, saved to embeddings_batches\embeddings_2600_2700.pkl
# ✅ Batch 2700 → 2800 done, saved to embeddings_batches\embeddings_2700_2800.pkl
# ✅ Batch 2800 → 2900 done, saved to embeddings_batches\embeddings_2800_2900.pkl
# ✅ Batch 2900 → 3000 done, saved to embeddings_batches\embeddings_2900_3000.pkl
# ✅ Batch 3000 → 3100 done, saved to embeddings_batches\embeddings_3000_3100.pkl
# ✅ Batch 3100 → 3200 done, saved to embeddings_batches\embeddings_3100_3200.pkl
# ✅ Batch 3200 → 3300 done, saved to embeddings_batches\embeddings_3200_3300.pkl
# ✅ Batch 3300 → 3400 done, saved to embeddings_batches\embeddings_3300_3400.pkl
# ✅ Batch 3400 → 3500 done, saved to embeddings_batches\embeddings_3400_3500.pkl
# ✅ Batch 3500 → 3600 done, saved to embeddings_batches\embeddings_3500_3600.pkl
# ✅ Batch 3600 → 3700 done, saved to embeddings_batches\embeddings_3600_3700.pkl
# ✅ Batch 3700 → 3800 done, saved to embeddings_batches\embeddings_3700_3800.pkl
# ✅ Batch 3800 → 3900 done, saved to embeddings_batches\embeddings_3800_3900.pkl
# ✅ Batch 3900 → 4000 done, saved to embeddings_batches\embeddings_3900_4000.pkl
# ✅ Batch 4000 → 4100 done, saved to embeddings_batches\embeddings_4000_4100.pkl
# ✅ Batch 4100 → 4200 done, saved to embeddings_batches\embeddings_4100_4200.pkl
# ✅ Batch 4200 → 4300 done, saved to embeddings_batches\embeddings_4200_4300.pkl
# ✅ Batch 4300 → 4400 done, saved to embeddings_batches\embeddings_4300_4400.pkl
# ✅ Batch 4400 → 4500 done, saved to embeddings_batches\embeddings_4400_4500.pkl
# ✅ Batch 4500 → 4600 done, saved to embeddings_batches\embeddings_4500_4600.pkl
# ✅ Batch 4600 → 4700 done, saved to embeddings_batches\embeddings_4600_4700.pkl
# ✅ Batch 4700 → 4800 done, saved to embeddings_batches\embeddings_4700_4800.pkl
# ✅ Batch 4800 → 4900 done, saved to embeddings_batches\embeddings_4800_4900.pkl
# ✅ Batch 4900 → 5000 done, saved to embeddings_batches\embeddings_4900_5000.pkl
# ✅ Batch 5000 → 5100 done, saved to embeddings_batches\embeddings_5000_5100.pkl
# ✅ Batch 5100 → 5200 done, saved to embeddings_batches\embeddings_5100_5200.pkl
# ✅ Batch 5200 → 5300 done, saved to embeddings_batches\embeddings_5200_5300.pkl
# ✅ Batch 5300 → 5400 done, saved to embeddings_batches\embeddings_5300_5400.pkl
# ✅ Batch 5400 → 5500 done, saved to embeddings_batches\embeddings_5400_5500.pkl
# ✅ Batch 5500 → 5600 done, saved to embeddings_batches\embeddings_5500_5600.pkl
# ✅ Batch 5600 → 5700 done, saved to embeddings_batches\embeddings_5600_5700.pkl
# ✅ Batch 5700 → 5800 done, saved to embeddings_batches\embeddings_5700_5800.pkl
# ✅ Batch 5800 → 5900 done, saved to embeddings_batches\embeddings_5800_5900.pkl
# ✅ Batch 5900 → 6000 done, saved to embeddings_batches\embeddings_5900_6000.pkl
# ✅ Batch 6000 → 6100 done, saved to embeddings_batches\embeddings_6000_6100.pkl
# ✅ Batch 6100 → 6200 done, saved to embeddings_batches\embeddings_6100_6200.pkl
# ✅ Batch 6200 → 6300 done, saved to embeddings_batches\embeddings_6200_6300.pkl
# ✅ Batch 6300 → 6400 done, saved to embeddings_batches\embeddings_6300_6400.pkl
# ✅ Batch 6400 → 6500 done, saved to embeddings_batches\embeddings_6400_6500.pkl
# ✅ Batch 6500 → 6600 done, saved to embeddings_batches\embeddings_6500_6600.pkl
# ✅ Batch 6600 → 6700 done, saved to embeddings_batches\embeddings_6600_6700.pkl
# ✅ Batch 6700 → 6800 done, saved to embeddings_batches\embeddings_6700_6800.pkl
# ✅ Batch 6800 → 6900 done, saved to embeddings_batches\embeddings_6800_6900.pkl
# ✅ Batch 6900 → 7000 done, saved to embeddings_batches\embeddings_6900_7000.pkl
# ✅ Batch 7000 → 7100 done, saved to embeddings_batches\embeddings_7000_7100.pkl
# ✅ Batch 7100 → 7200 done, saved to embeddings_batches\embeddings_7100_7200.pkl
# ✅ Batch 7200 → 7300 done, saved to embeddings_batches\embeddings_7200_7300.pkl
# ✅ Batch 7300 → 7400 done, saved to embeddings_batches\embeddings_7300_7400.pkl
# ✅ Batch 7400 → 7500 done, saved to embeddings_batches\embeddings_7400_7500.pkl
# ✅ Batch 7500 → 7600 done, saved to embeddings_batches\embeddings_7500_7600.pkl
# ✅ Batch 7600 → 7700 done, saved to embeddings_batches\embeddings_7600_7700.pkl
# ✅ Batch 7700 → 7800 done, saved to embeddings_batches\embeddings_7700_7800.pkl
# ✅ Batch 7800 → 7900 done, saved to embeddings_batches\embeddings_7800_7900.pkl
# ✅ Batch 7900 → 8000 done, saved to embeddings_batches\embeddings_7900_8000.pkl
# ✅ Batch 8000 → 8100 done, saved to embeddings_batches\embeddings_8000_8100.pkl
# ✅ Batch 8100 → 8200 done, saved to embeddings_batches\embeddings_8100_8200.pkl
# ✅ Batch 8200 → 8300 done, saved to embeddings_batches\embeddings_8200_8300.pkl
# ✅ Batch 8300 → 8400 done, saved to embeddings_batches\embeddings_8300_8400.pkl
# ✅ Batch 8400 → 8500 done, saved to embeddings_batches\embeddings_8400_8500.pkl
# ✅ Batch 8500 → 8600 done, saved to embeddings_batches\embeddings_8500_8600.pkl
# ✅ Batch 8600 → 8700 done, saved to embeddings_batches\embeddings_8600_8700.pkl
# ✅ Batch 8700 → 8800 done, saved to embeddings_batches\embeddings_8700_8800.pkl
# ✅ Batch 8800 → 8900 done, saved to embeddings_batches\embeddings_8800_8900.pkl
# ✅ Batch 8900 → 9000 done, saved to embeddings_batches\embeddings_8900_9000.pkl
# ✅ Batch 9000 → 9100 done, saved to embeddings_batches\embeddings_9000_9100.pkl
# ✅ Batch 9100 → 9200 done, saved to embeddings_batches\embeddings_9100_9200.pkl
# ✅ Batch 9200 → 9300 done, saved to embeddings_batches\embeddings_9200_9300.pkl
# ✅ Batch 9300 → 9400 done, saved to embeddings_batches\embeddings_9300_9400.pkl
# ✅ Batch 9400 → 9500 done, saved to embeddings_batches\embeddings_9400_9500.pkl
# ✅ Batch 9500 → 9600 done, saved to embeddings_batches\embeddings_9500_9600.pkl
# ✅ Batch 9600 → 9700 done, saved to embeddings_batches\embeddings_9600_9700.pkl
# ✅ Batch 9700 → 9800 done, saved to embeddings_batches\embeddings_9700_9800.pkl
# ✅ Batch 9800 → 9900 done, saved to embeddings_batches\embeddings_9800_9900.pkl
# ✅ Batch 9900 → 10000 done, saved to embeddings_batches\embeddings_9900_10000.pkl
# ✅ Batch 10000 → 10100 done, saved to embeddings_batches\embeddings_10000_10100.pkl
# ✅ Batch 10100 → 10200 done, saved to embeddings_batches\embeddings_10100_10200.pkl
# ✅ Batch 10200 → 10300 done, saved to embeddings_batches\embeddings_10200_10300.pkl
# ✅ Batch 10300 → 10400 done, saved to embeddings_batches\embeddings_10300_10400.pkl
# ✅ Batch 10400 → 10500 done, saved to embeddings_batches\embeddings_10400_10500.pkl
# ✅ Batch 10500 → 10600 done, saved to embeddings_batches\embeddings_10500_10600.pkl
# ✅ Batch 10600 → 10700 done, saved to embeddings_batches\embeddings_10600_10700.pkl
# ✅ Batch 10700 → 10800 done, saved to embeddings_batches\embeddings_10700_10800.pkl
# ✅ Batch 10800 → 10900 done, saved to embeddings_batches\embeddings_10800_10900.pkl
# ✅ Batch 10900 → 11000 done, saved to embeddings_batches\embeddings_10900_11000.pkl
# ✅ Batch 11000 → 11100 done, saved to embeddings_batches\embeddings_11000_11100.pkl
# ✅ Batch 11100 → 11200 done, saved to embeddings_batches\embeddings_11100_11200.pkl
# ✅ Batch 11200 → 11300 done, saved to embeddings_batches\embeddings_11200_11300.pkl
# ✅ Batch 11300 → 11400 done, saved to embeddings_batches\embeddings_11300_11400.pkl
# ✅ Batch 11400 → 11500 done, saved to embeddings_batches\embeddings_11400_11500.pkl
# ✅ Batch 11500 → 11600 done, saved to embeddings_batches\embeddings_11500_11600.pkl
# ✅ Batch 11600 → 11700 done, saved to embeddings_batches\embeddings_11600_11700.pkl
# ✅ Batch 11700 → 11800 done, saved to embeddings_batches\embeddings_11700_11800.pkl
# ✅ Batch 11800 → 11900 done, saved to embeddings_batches\embeddings_11800_11900.pkl
# ✅ Batch 11900 → 12000 done, saved to embeddings_batches\embeddings_11900_12000.pkl
# ✅ Batch 12000 → 12100 done, saved to embeddings_batches\embeddings_12000_12100.pkl
# ✅ Batch 12100 → 12200 done, saved to embeddings_batches\embeddings_12100_12200.pkl
# ✅ Batch 12200 → 12300 done, saved to embeddings_batches\embeddings_12200_12300.pkl
# ✅ Batch 12300 → 12400 done, saved to embeddings_batches\embeddings_12300_12400.pkl
# ✅ Batch 12400 → 12500 done, saved to embeddings_batches\embeddings_12400_12500.pkl
# ✅ Batch 12500 → 12600 done, saved to embeddings_batches\embeddings_12500_12600.pkl
# ✅ Batch 12600 → 12700 done, saved to embeddings_batches\embeddings_12600_12700.pkl
# ✅ Batch 12700 → 12800 done, saved to embeddings_batches\embeddings_12700_12800.pkl
# ✅ Batch 12800 → 12900 done, saved to embeddings_batches\embeddings_12800_12900.pkl
# ✅ Batch 12900 → 13000 done, saved to embeddings_batches\embeddings_12900_13000.pkl
# ✅ Batch 13000 → 13100 done, saved to embeddings_batches\embeddings_13000_13100.pkl
# ✅ Batch 13100 → 13200 done, saved to embeddings_batches\embeddings_13100_13200.pkl
# ✅ Batch 13200 → 13300 done, saved to embeddings_batches\embeddings_13200_13300.pkl
# ✅ Batch 13300 → 13400 done, saved to embeddings_batches\embeddings_13300_13400.pkl
# ✅ Batch 13400 → 13500 done, saved to embeddings_batches\embeddings_13400_13500.pkl
# ✅ Batch 13500 → 13600 done, saved to embeddings_batches\embeddings_13500_13600.pkl
# ✅ Batch 13600 → 13700 done, saved to embeddings_batches\embeddings_13600_13700.pkl
# ✅ Batch 13700 → 13800 done, saved to embeddings_batches\embeddings_13700_13800.pkl
# ✅ Batch 13800 → 13900 done, saved to embeddings_batches\embeddings_13800_13900.pkl
# ✅ Batch 13900 → 14000 done, saved to embeddings_batches\embeddings_13900_14000.pkl
# ✅ Batch 14000 → 14100 done, saved to embeddings_batches\embeddings_14000_14100.pkl
# ✅ Batch 14100 → 14200 done, saved to embeddings_batches\embeddings_14100_14200.pkl
# ✅ Batch 14200 → 14300 done, saved to embeddings_batches\embeddings_14200_14300.pkl
# ✅ Batch 14300 → 14400 done, saved to embeddings_batches\embeddings_14300_14400.pkl
# ✅ Batch 14400 → 14500 done, saved to embeddings_batches\embeddings_14400_14500.pkl
# ✅ Batch 14500 → 14600 done, saved to embeddings_batches\embeddings_14500_14600.pkl
# ✅ Batch 14600 → 14700 done, saved to embeddings_batches\embeddings_14600_14700.pkl
# ✅ Batch 14700 → 14800 done, saved to embeddings_batches\embeddings_14700_14800.pkl
# ✅ Batch 14800 → 14900 done, saved to embeddings_batches\embeddings_14800_14900.pkl
# ✅ Batch 14900 → 15000 done, saved to embeddings_batches\embeddings_14900_15000.pkl
# ✅ Batch 15000 → 15100 done, saved to embeddings_batches\embeddings_15000_15100.pkl
# ✅ Batch 15100 → 15200 done, saved to embeddings_batches\embeddings_15100_15200.pkl
# ✅ Batch 15200 → 15300 done, saved to embeddings_batches\embeddings_15200_15300.pkl
# ✅ Batch 15300 → 15400 done, saved to embeddings_batches\embeddings_15300_15400.pkl
# ✅ Batch 15400 → 15500 done, saved to embeddings_batches\embeddings_15400_15500.pkl
# ✅ Batch 15500 → 15600 done, saved to embeddings_batches\embeddings_15500_15600.pkl
# ✅ Batch 15600 → 15700 done, saved to embeddings_batches\embeddings_15600_15700.pkl
# ✅ Batch 15700 → 15800 done, saved to embeddings_batches\embeddings_15700_15800.pkl
# ✅ Batch 15800 → 15900 done, saved to embeddings_batches\embeddings_15800_15900.pkl
# ✅ Batch 15900 → 16000 done, saved to embeddings_batches\embeddings_15900_16000.pkl
# ✅ Batch 16000 → 16100 done, saved to embeddings_batches\embeddings_16000_16100.pkl
# ✅ Batch 16100 → 16200 done, saved to embeddings_batches\embeddings_16100_16200.pkl
# ✅ Batch 16200 → 16300 done, saved to embeddings_batches\embeddings_16200_16300.pkl
# ✅ Batch 16300 → 16400 done, saved to embeddings_batches\embeddings_16300_16400.pkl
# ✅ Batch 16400 → 16500 done, saved to embeddings_batches\embeddings_16400_16500.pkl
# ✅ Batch 16500 → 16600 done, saved to embeddings_batches\embeddings_16500_16600.pkl
# ✅ Batch 16600 → 16700 done, saved to embeddings_batches\embeddings_16600_16700.pkl
# ✅ Batch 16700 → 16800 done, saved to embeddings_batches\embeddings_16700_16800.pkl
# ✅ Batch 16800 → 16900 done, saved to embeddings_batches\embeddings_16800_16900.pkl
# ✅ Batch 16900 → 17000 done, saved to embeddings_batches\embeddings_16900_17000.pkl
# ✅ Batch 17000 → 17100 done, saved to embeddings_batches\embeddings_17000_17100.pkl
# ✅ Batch 17100 → 17200 done, saved to embeddings_batches\embeddings_17100_17200.pkl
# ✅ Batch 17200 → 17300 done, saved to embeddings_batches\embeddings_17200_17300.pkl
# ✅ Batch 17300 → 17400 done, saved to embeddings_batches\embeddings_17300_17400.pkl
# ✅ Batch 17400 → 17500 done, saved to embeddings_batches\embeddings_17400_17500.pkl
# ✅ Batch 17500 → 17600 done, saved to embeddings_batches\embeddings_17500_17600.pkl
# ✅ Batch 17600 → 17700 done, saved to embeddings_batches\embeddings_17600_17700.pkl
# ✅ Batch 17700 → 17800 done, saved to embeddings_batches\embeddings_17700_17800.pkl
# ✅ Batch 17800 → 17900 done, saved to embeddings_batches\embeddings_17800_17900.pkl
# ✅ Batch 17900 → 18000 done, saved to embeddings_batches\embeddings_17900_18000.pkl
# ✅ Batch 18000 → 18100 done, saved to embeddings_batches\embeddings_18000_18100.pkl
# ✅ Batch 18100 → 18200 done, saved to embeddings_batches\embeddings_18100_18200.pkl
# ✅ Batch 18200 → 18300 done, saved to embeddings_batches\embeddings_18200_18300.pkl
# ✅ Batch 18300 → 18400 done, saved to embeddings_batches\embeddings_18300_18400.pkl
# ✅ Batch 18400 → 18500 done, saved to embeddings_batches\embeddings_18400_18500.pkl
# ✅ Batch 18500 → 18600 done, saved to embeddings_batches\embeddings_18500_18600.pkl
# ✅ Batch 18600 → 18700 done, saved to embeddings_batches\embeddings_18600_18700.pkl
# ✅ Batch 18700 → 18800 done, saved to embeddings_batches\embeddings_18700_18800.pkl
# ✅ Batch 18800 → 18900 done, saved to embeddings_batches\embeddings_18800_18900.pkl
# ✅ Batch 18900 → 19000 done, saved to embeddings_batches\embeddings_18900_19000.pkl
# ✅ Batch 19000 → 19100 done, saved to embeddings_batches\embeddings_19000_19100.pkl
# ✅ Batch 19100 → 19200 done, saved to embeddings_batches\embeddings_19100_19200.pkl
# ✅ Batch 19200 → 19300 done, saved to embeddings_batches\embeddings_19200_19300.pkl
# ✅ Batch 19300 → 19400 done, saved to embeddings_batches\embeddings_19300_19400.pkl
# ✅ Batch 19400 → 19500 done, saved to embeddings_batches\embeddings_19400_19500.pkl
# ✅ Batch 19500 → 19600 done, saved to embeddings_batches\embeddings_19500_19600.pkl
# ✅ Batch 19600 → 19700 done, saved to embeddings_batches\embeddings_19600_19700.pkl
# ✅ Batch 19700 → 19800 done, saved to embeddings_batches\embeddings_19700_19800.pkl
# ✅ Batch 19800 → 19900 done, saved to embeddings_batches\embeddings_19800_19900.pkl
# ✅ Batch 19900 → 20000 done, saved to embeddings_batches\embeddings_19900_20000.pkl
# ✅ Batch 20000 → 20100 done, saved to embeddings_batches\embeddings_20000_20100.pkl
# ✅ Batch 20100 → 20200 done, saved to embeddings_batches\embeddings_20100_20200.pkl
# ✅ Batch 20200 → 20300 done, saved to embeddings_batches\embeddings_20200_20300.pkl
# ✅ Batch 20300 → 20400 done, saved to embeddings_batches\embeddings_20300_20400.pkl
# ✅ Batch 20400 → 20500 done, saved to embeddings_batches\embeddings_20400_20500.pkl
# ✅ Batch 20500 → 20600 done, saved to embeddings_batches\embeddings_20500_20600.pkl
# ✅ Batch 20600 → 20700 done, saved to embeddings_batches\embeddings_20600_20700.pkl
# ✅ Batch 20700 → 20800 done, saved to embeddings_batches\embeddings_20700_20800.pkl
# ✅ Batch 20800 → 20900 done, saved to embeddings_batches\embeddings_20800_20900.pkl
# ✅ Batch 20900 → 21000 done, saved to embeddings_batches\embeddings_20900_21000.pkl
# ✅ Batch 21000 → 21100 done, saved to embeddings_batches\embeddings_21000_21100.pkl
# ✅ Batch 21100 → 21200 done, saved to embeddings_batches\embeddings_21100_21200.pkl
# ✅ Batch 21200 → 21300 done, saved to embeddings_batches\embeddings_21200_21300.pkl
# ✅ Batch 21300 → 21400 done, saved to embeddings_batches\embeddings_21300_21400.pkl
# ✅ Batch 21400 → 21500 done, saved to embeddings_batches\embeddings_21400_21500.pkl
# ✅ Batch 21500 → 21600 done, saved to embeddings_batches\embeddings_21500_21600.pkl
# ✅ Batch 21600 → 21700 done, saved to embeddings_batches\embeddings_21600_21700.pkl
# ✅ Batch 21700 → 21800 done, saved to embeddings_batches\embeddings_21700_21800.pkl
# ✅ Batch 21800 → 21900 done, saved to embeddings_batches\embeddings_21800_21900.pkl
# ✅ Batch 21900 → 22000 done, saved to embeddings_batches\embeddings_21900_22000.pkl
# ✅ Batch 22000 → 22100 done, saved to embeddings_batches\embeddings_22000_22100.pkl
# ✅ Batch 22100 → 22200 done, saved to embeddings_batches\embeddings_22100_22200.pkl
# ✅ Batch 22200 → 22300 done, saved to embeddings_batches\embeddings_22200_22300.pkl
# ✅ Batch 22300 → 22400 done, saved to embeddings_batches\embeddings_22300_22400.pkl
# ✅ Batch 22400 → 22500 done, saved to embeddings_batches\embeddings_22400_22500.pkl
# ✅ Batch 22500 → 22600 done, saved to embeddings_batches\embeddings_22500_22600.pkl
# ✅ Batch 22600 → 22700 done, saved to embeddings_batches\embeddings_22600_22700.pkl
# ✅ Batch 22700 → 22800 done, saved to embeddings_batches\embeddings_22700_22800.pkl
# ✅ Batch 22800 → 22900 done, saved to embeddings_batches\embeddings_22800_22900.pkl
# ✅ Batch 22900 → 23000 done, saved to embeddings_batches\embeddings_22900_23000.pkl
# ✅ Batch 23000 → 23100 done, saved to embeddings_batches\embeddings_23000_23100.pkl
# ✅ Batch 23100 → 23200 done, saved to embeddings_batches\embeddings_23100_23200.pkl
# ✅ Batch 23200 → 23300 done, saved to embeddings_batches\embeddings_23200_23300.pkl
# ✅ Batch 23300 → 23400 done, saved to embeddings_batches\embeddings_23300_23400.pkl
# ✅ Batch 23400 → 23500 done, saved to embeddings_batches\embeddings_23400_23500.pkl
# ✅ Batch 23500 → 23600 done, saved to embeddings_batches\embeddings_23500_23600.pkl
# ✅ Batch 23600 → 23700 done, saved to embeddings_batches\embeddings_23600_23700.pkl
# ✅ Batch 23700 → 23800 done, saved to embeddings_batches\embeddings_23700_23800.pkl
# ✅ Batch 23800 → 23900 done, saved to embeddings_batches\embeddings_23800_23900.pkl
# ✅ Batch 23900 → 24000 done, saved to embeddings_batches\embeddings_23900_24000.pkl
# ✅ Batch 24000 → 24100 done, saved to embeddings_batches\embeddings_24000_24100.pkl
# ✅ Batch 24100 → 24200 done, saved to embeddings_batches\embeddings_24100_24200.pkl
# ✅ Batch 24200 → 24300 done, saved to embeddings_batches\embeddings_24200_24300.pkl
# ✅ Batch 24300 → 24400 done, saved to embeddings_batches\embeddings_24300_24400.pkl
# ✅ Batch 24400 → 24500 done, saved to embeddings_batches\embeddings_24400_24500.pkl
# ✅ Batch 24500 → 24600 done, saved to embeddings_batches\embeddings_24500_24600.pkl
# ✅ Batch 24600 → 24700 done, saved to embeddings_batches\embeddings_24600_24700.pkl
# ✅ Batch 24700 → 24800 done, saved to embeddings_batches\embeddings_24700_24800.pkl
# ✅ Batch 24800 → 24900 done, saved to embeddings_batches\embeddings_24800_24900.pkl
# ✅ Batch 24900 → 25000 done, saved to embeddings_batches\embeddings_24900_25000.pkl
# ✅ Batch 25000 → 25100 done, saved to embeddings_batches\embeddings_25000_25100.pkl
# ✅ Batch 25100 → 25200 done, saved to embeddings_batches\embeddings_25100_25200.pkl
# ✅ Batch 25200 → 25300 done, saved to embeddings_batches\embeddings_25200_25300.pkl
# ✅ Batch 25300 → 25400 done, saved to embeddings_batches\embeddings_25300_25400.pkl
# ✅ Batch 25400 → 25500 done, saved to embeddings_batches\embeddings_25400_25500.pkl
# ✅ Batch 25500 → 25600 done, saved to embeddings_batches\embeddings_25500_25600.pkl
# ✅ Batch 25600 → 25700 done, saved to embeddings_batches\embeddings_25600_25700.pkl
# ✅ Batch 25700 → 25800 done, saved to embeddings_batches\embeddings_25700_25800.pkl
# ✅ Batch 25800 → 25900 done, saved to embeddings_batches\embeddings_25800_25900.pkl
# ✅ Batch 25900 → 26000 done, saved to embeddings_batches\embeddings_25900_26000.pkl
# ✅ Batch 26000 → 26100 done, saved to embeddings_batches\embeddings_26000_26100.pkl
# ✅ Batch 26100 → 26200 done, saved to embeddings_batches\embeddings_26100_26200.pkl
# ✅ Batch 26200 → 26300 done, saved to embeddings_batches\embeddings_26200_26300.pkl
# ✅ Batch 26300 → 26400 done, saved to embeddings_batches\embeddings_26300_26400.pkl
# ✅ Batch 26400 → 26500 done, saved to embeddings_batches\embeddings_26400_26500.pkl
# ✅ Batch 26500 → 26600 done, saved to embeddings_batches\embeddings_26500_26600.pkl
# ✅ Batch 26600 → 26700 done, saved to embeddings_batches\embeddings_26600_26700.pkl
# ✅ Batch 26700 → 26800 done, saved to embeddings_batches\embeddings_26700_26800.pkl
# ✅ Batch 26800 → 26900 done, saved to embeddings_batches\embeddings_26800_26900.pkl
# ✅ Batch 26900 → 27000 done, saved to embeddings_batches\embeddings_26900_27000.pkl
# ✅ Batch 27000 → 27100 done, saved to embeddings_batches\embeddings_27000_27100.pkl
# ✅ Batch 27100 → 27200 done, saved to embeddings_batches\embeddings_27100_27200.pkl
# ✅ Batch 27200 → 27300 done, saved to embeddings_batches\embeddings_27200_27300.pkl
# ✅ Batch 27300 → 27400 done, saved to embeddings_batches\embeddings_27300_27400.pkl
# ✅ Batch 27400 → 27500 done, saved to embeddings_batches\embeddings_27400_27500.pkl
# ✅ Batch 27500 → 27600 done, saved to embeddings_batches\embeddings_27500_27600.pkl
# ✅ Batch 27600 → 27700 done, saved to embeddings_batches\embeddings_27600_27700.pkl
# ✅ Batch 27700 → 27800 done, saved to embeddings_batches\embeddings_27700_27800.pkl
# ✅ Batch 27800 → 27900 done, saved to embeddings_batches\embeddings_27800_27900.pkl
# ✅ Batch 27900 → 28000 done, saved to embeddings_batches\embeddings_27900_28000.pkl
# ✅ Batch 28000 → 28100 done, saved to embeddings_batches\embeddings_28000_28100.pkl
# ✅ Batch 28100 → 28200 done, saved to embeddings_batches\embeddings_28100_28200.pkl
# ✅ Batch 28200 → 28300 done, saved to embeddings_batches\embeddings_28200_28300.pkl
# ✅ Batch 28300 → 28400 done, saved to embeddings_batches\embeddings_28300_28400.pkl
# ✅ Batch 28400 → 28500 done, saved to embeddings_batches\embeddings_28400_28500.pkl
# ✅ Batch 28500 → 28600 done, saved to embeddings_batches\embeddings_28500_28600.pkl
# ✅ Batch 28600 → 28700 done, saved to embeddings_batches\embeddings_28600_28700.pkl
# ✅ Batch 28700 → 28800 done, saved to embeddings_batches\embeddings_28700_28800.pkl
# ✅ Batch 28800 → 28900 done, saved to embeddings_batches\embeddings_28800_28900.pkl
# ✅ Batch 28900 → 29000 done, saved to embeddings_batches\embeddings_28900_29000.pkl
# ✅ Batch 29000 → 29100 done, saved to embeddings_batches\embeddings_29000_29100.pkl
# ✅ Batch 29100 → 29200 done, saved to embeddings_batches\embeddings_29100_29200.pkl
# ✅ Batch 29200 → 29300 done, saved to embeddings_batches\embeddings_29200_29300.pkl
# ✅ Batch 29300 → 29400 done, saved to embeddings_batches\embeddings_29300_29400.pkl
# ✅ Batch 29400 → 29500 done, saved to embeddings_batches\embeddings_29400_29500.pkl
# ✅ Batch 29500 → 29600 done, saved to embeddings_batches\embeddings_29500_29600.pkl
# ✅ Batch 29600 → 29700 done, saved to embeddings_batches\embeddings_29600_29700.pkl
# ✅ Batch 29700 → 29800 done, saved to embeddings_batches\embeddings_29700_29800.pkl
# ✅ Batch 29800 → 29900 done, saved to embeddings_batches\embeddings_29800_29900.pkl
# ✅ Batch 29900 → 30000 done, saved to embeddings_batches\embeddings_29900_30000.pkl
# ✅ Batch 30000 → 30100 done, saved to embeddings_batches\embeddings_30000_30100.pkl
# ✅ Batch 30100 → 30200 done, saved to embeddings_batches\embeddings_30100_30200.pkl
# ✅ Batch 30200 → 30300 done, saved to embeddings_batches\embeddings_30200_30300.pkl
# ✅ Batch 30300 → 30400 done, saved to embeddings_batches\embeddings_30300_30400.pkl
# ✅ Batch 30400 → 30500 done, saved to embeddings_batches\embeddings_30400_30500.pkl
# ✅ Batch 30500 → 30600 done, saved to embeddings_batches\embeddings_30500_30600.pkl
# ✅ Batch 30600 → 30700 done, saved to embeddings_batches\embeddings_30600_30700.pkl
# ✅ Batch 30700 → 30800 done, saved to embeddings_batches\embeddings_30700_30800.pkl
# ✅ Batch 30800 → 30900 done, saved to embeddings_batches\embeddings_30800_30900.pkl
# ✅ Batch 30900 → 31000 done, saved to embeddings_batches\embeddings_30900_31000.pkl
# ✅ Batch 31000 → 31100 done, saved to embeddings_batches\embeddings_31000_31100.pkl
# ✅ Batch 31100 → 31200 done, saved to embeddings_batches\embeddings_31100_31200.pkl
# ✅ Batch 31200 → 31300 done, saved to embeddings_batches\embeddings_31200_31300.pkl
# ✅ Batch 31300 → 31400 done, saved to embeddings_batches\embeddings_31300_31400.pkl
# ✅ Batch 31400 → 31500 done, saved to embeddings_batches\embeddings_31400_31500.pkl
# ✅ Batch 31500 → 31600 done, saved to embeddings_batches\embeddings_31500_31600.pkl
# ✅ Batch 31600 → 31700 done, saved to embeddings_batches\embeddings_31600_31700.pkl
# ✅ Batch 31700 → 31800 done, saved to embeddings_batches\embeddings_31700_31800.pkl
# ✅ Batch 31800 → 31900 done, saved to embeddings_batches\embeddings_31800_31900.pkl
# ✅ Batch 31900 → 32000 done, saved to embeddings_batches\embeddings_31900_32000.pkl
# ✅ Batch 32000 → 32100 done, saved to embeddings_batches\embeddings_32000_32100.pkl
# ✅ Batch 32100 → 32200 done, saved to embeddings_batches\embeddings_32100_32200.pkl
# ✅ Batch 32200 → 32300 done, saved to embeddings_batches\embeddings_32200_32300.pkl
# ✅ Batch 32300 → 32400 done, saved to embeddings_batches\embeddings_32300_32400.pkl
# ✅ Batch 32400 → 32500 done, saved to embeddings_batches\embeddings_32400_32500.pkl
# ✅ Batch 32500 → 32600 done, saved to embeddings_batches\embeddings_32500_32600.pkl
# ✅ Batch 32600 → 32700 done, saved to embeddings_batches\embeddings_32600_32700.pkl
# ✅ Batch 32700 → 32800 done, saved to embeddings_batches\embeddings_32700_32800.pkl
# ✅ Batch 32800 → 32900 done, saved to embeddings_batches\embeddings_32800_32900.pkl
# ✅ Batch 32900 → 33000 done, saved to embeddings_batches\embeddings_32900_33000.pkl
# ✅ Batch 33000 → 33100 done, saved to embeddings_batches\embeddings_33000_33100.pkl
# ✅ Batch 33100 → 33200 done, saved to embeddings_batches\embeddings_33100_33200.pkl
# ✅ Batch 33200 → 33300 done, saved to embeddings_batches\embeddings_33200_33300.pkl
# ✅ Batch 33300 → 33400 done, saved to embeddings_batches\embeddings_33300_33400.pkl
# ✅ Batch 33400 → 33500 done, saved to embeddings_batches\embeddings_33400_33500.pkl
# ✅ Batch 33500 → 33600 done, saved to embeddings_batches\embeddings_33500_33600.pkl
# ✅ Batch 33600 → 33700 done, saved to embeddings_batches\embeddings_33600_33700.pkl
# ✅ Batch 33700 → 33800 done, saved to embeddings_batches\embeddings_33700_33800.pkl
# ✅ Batch 33800 → 33900 done, saved to embeddings_batches\embeddings_33800_33900.pkl
# ✅ Batch 33900 → 34000 done, saved to embeddings_batches\embeddings_33900_34000.pkl
# ✅ Batch 34000 → 34100 done, saved to embeddings_batches\embeddings_34000_34100.pkl
# ✅ Batch 34100 → 34200 done, saved to embeddings_batches\embeddings_34100_34200.pkl
# ✅ Batch 34200 → 34300 done, saved to embeddings_batches\embeddings_34200_34300.pkl
# ✅ Batch 34300 → 34400 done, saved to embeddings_batches\embeddings_34300_34400.pkl
# ✅ Batch 34400 → 34500 done, saved to embeddings_batches\embeddings_34400_34500.pkl
# ✅ Batch 34500 → 34600 done, saved to embeddings_batches\embeddings_34500_34600.pkl
# ✅ Batch 34600 → 34700 done, saved to embeddings_batches\embeddings_34600_34700.pkl
# ✅ Batch 34700 → 34800 done, saved to embeddings_batches\embeddings_34700_34800.pkl
# ✅ Batch 34800 → 34900 done, saved to embeddings_batches\embeddings_34800_34900.pkl
# ✅ Batch 34900 → 35000 done, saved to embeddings_batches\embeddings_34900_35000.pkl
# ✅ Batch 35000 → 35100 done, saved to embeddings_batches\embeddings_35000_35100.pkl
# ✅ Batch 35100 → 35200 done, saved to embeddings_batches\embeddings_35100_35200.pkl
# ✅ Batch 35200 → 35300 done, saved to embeddings_batches\embeddings_35200_35300.pkl
# ✅ Batch 35300 → 35400 done, saved to embeddings_batches\embeddings_35300_35400.pkl
# ✅ Batch 35400 → 35500 done, saved to embeddings_batches\embeddings_35400_35500.pkl
# ✅ Batch 35500 → 35600 done, saved to embeddings_batches\embeddings_35500_35600.pkl
# ✅ Batch 35600 → 35700 done, saved to embeddings_batches\embeddings_35600_35700.pkl
# ✅ Batch 35700 → 35800 done, saved to embeddings_batches\embeddings_35700_35800.pkl
# ✅ Batch 35800 → 35900 done, saved to embeddings_batches\embeddings_35800_35900.pkl
# ✅ Batch 35900 → 36000 done, saved to embeddings_batches\embeddings_35900_36000.pkl
# ✅ Batch 36000 → 36100 done, saved to embeddings_batches\embeddings_36000_36100.pkl
# ✅ Batch 36100 → 36200 done, saved to embeddings_batches\embeddings_36100_36200.pkl
# ✅ Batch 36200 → 36300 done, saved to embeddings_batches\embeddings_36200_36300.pkl
# ✅ Batch 36300 → 36400 done, saved to embeddings_batches\embeddings_36300_36400.pkl
# ✅ Batch 36400 → 36500 done, saved to embeddings_batches\embeddings_36400_36500.pkl
# ✅ Batch 36500 → 36600 done, saved to embeddings_batches\embeddings_36500_36600.pkl
# ✅ Batch 36600 → 36700 done, saved to embeddings_batches\embeddings_36600_36700.pkl
# ✅ Batch 36700 → 36800 done, saved to embeddings_batches\embeddings_36700_36800.pkl
# ✅ Batch 36800 → 36900 done, saved to embeddings_batches\embeddings_36800_36900.pkl
# ✅ Batch 36900 → 37000 done, saved to embeddings_batches\embeddings_36900_37000.pkl
# ✅ Batch 37000 → 37100 done, saved to embeddings_batches\embeddings_37000_37100.pkl
# ✅ Batch 37100 → 37200 done, saved to embeddings_batches\embeddings_37100_37200.pkl
# ✅ Batch 37200 → 37300 done, saved to embeddings_batches\embeddings_37200_37300.pkl
# ✅ Batch 37300 → 37400 done, saved to embeddings_batches\embeddings_37300_37400.pkl
# ✅ Batch 37400 → 37500 done, saved to embeddings_batches\embeddings_37400_37500.pkl
# ✅ Batch 37500 → 37600 done, saved to embeddings_batches\embeddings_37500_37600.pkl
# ✅ Batch 37600 → 37700 done, saved to embeddings_batches\embeddings_37600_37700.pkl
# ✅ Batch 37700 → 37800 done, saved to embeddings_batches\embeddings_37700_37800.pkl
# ✅ Batch 37800 → 37900 done, saved to embeddings_batches\embeddings_37800_37900.pkl
# ✅ Batch 37900 → 38000 done, saved to embeddings_batches\embeddings_37900_38000.pkl
# ✅ Batch 38000 → 38100 done, saved to embeddings_batches\embeddings_38000_38100.pkl
# ✅ Batch 38100 → 38200 done, saved to embeddings_batches\embeddings_38100_38200.pkl
# ✅ Batch 38200 → 38300 done, saved to embeddings_batches\embeddings_38200_38300.pkl
# ✅ Batch 38300 → 38400 done, saved to embeddings_batches\embeddings_38300_38400.pkl
# ✅ Batch 38400 → 38500 done, saved to embeddings_batches\embeddings_38400_38500.pkl
# ✅ Batch 38500 → 38600 done, saved to embeddings_batches\embeddings_38500_38600.pkl
# ✅ Batch 38600 → 38700 done, saved to embeddings_batches\embeddings_38600_38700.pkl
# ✅ Batch 38700 → 38800 done, saved to embeddings_batches\embeddings_38700_38800.pkl
# ✅ Batch 38800 → 38900 done, saved to embeddings_batches\embeddings_38800_38900.pkl
# ✅ Batch 38900 → 39000 done, saved to embeddings_batches\embeddings_38900_39000.pkl
# ✅ Batch 39000 → 39100 done, saved to embeddings_batches\embeddings_39000_39100.pkl
# ✅ Batch 39100 → 39200 done, saved to embeddings_batches\embeddings_39100_39200.pkl
# ✅ Batch 39200 → 39300 done, saved to embeddings_batches\embeddings_39200_39300.pkl
# ✅ Batch 39300 → 39400 done, saved to embeddings_batches\embeddings_39300_39400.pkl
# ✅ Batch 39400 → 39500 done, saved to embeddings_batches\embeddings_39400_39500.pkl
# ✅ Batch 39500 → 39600 done, saved to embeddings_batches\embeddings_39500_39600.pkl
# ✅ Batch 39600 → 39700 done, saved to embeddings_batches\embeddings_39600_39700.pkl
# ✅ Batch 39700 → 39800 done, saved to embeddings_batches\embeddings_39700_39800.pkl
# ✅ Batch 39800 → 39900 done, saved to embeddings_batches\embeddings_39800_39900.pkl
# ✅ Batch 39900 → 40000 done, saved to embeddings_batches\embeddings_39900_40000.pkl
# ✅ Batch 40000 → 40100 done, saved to embeddings_batches\embeddings_40000_40100.pkl
# ✅ Batch 40100 → 40200 done, saved to embeddings_batches\embeddings_40100_40200.pkl
# ✅ Batch 40200 → 40300 done, saved to embeddings_batches\embeddings_40200_40300.pkl
# ✅ Batch 40300 → 40400 done, saved to embeddings_batches\embeddings_40300_40400.pkl
# ✅ Batch 40400 → 40500 done, saved to embeddings_batches\embeddings_40400_40500.pkl
# ✅ Batch 40500 → 40600 done, saved to embeddings_batches\embeddings_40500_40600.pkl
# ✅ Batch 40600 → 40700 done, saved to embeddings_batches\embeddings_40600_40700.pkl
# ✅ Batch 40700 → 40800 done, saved to embeddings_batches\embeddings_40700_40800.pkl
# ✅ Batch 40800 → 40900 done, saved to embeddings_batches\embeddings_40800_40900.pkl
# ✅ Batch 40900 → 41000 done, saved to embeddings_batches\embeddings_40900_41000.pkl
# ✅ Batch 41000 → 41100 done, saved to embeddings_batches\embeddings_41000_41100.pkl
# ✅ Batch 41100 → 41200 done, saved to embeddings_batches\embeddings_41100_41200.pkl
# ✅ Batch 41200 → 41300 done, saved to embeddings_batches\embeddings_41200_41300.pkl
# ✅ Batch 41300 → 41400 done, saved to embeddings_batches\embeddings_41300_41400.pkl
# ✅ Batch 41400 → 41500 done, saved to embeddings_batches\embeddings_41400_41500.pkl
# ✅ Batch 41500 → 41600 done, saved to embeddings_batches\embeddings_41500_41600.pkl
# ✅ Batch 41600 → 41700 done, saved to embeddings_batches\embeddings_41600_41700.pkl
# ✅ Batch 41700 → 41800 done, saved to embeddings_batches\embeddings_41700_41800.pkl
# ✅ Batch 41800 → 41900 done, saved to embeddings_batches\embeddings_41800_41900.pkl
# ✅ Batch 41900 → 42000 done, saved to embeddings_batches\embeddings_41900_42000.pkl
# ✅ Batch 42000 → 42100 done, saved to embeddings_batches\embeddings_42000_42100.pkl
# ✅ Batch 42100 → 42200 done, saved to embeddings_batches\embeddings_42100_42200.pkl
# ✅ Batch 42200 → 42300 done, saved to embeddings_batches\embeddings_42200_42300.pkl
# ✅ Batch 42300 → 42400 done, saved to embeddings_batches\embeddings_42300_42400.pkl
# ✅ Batch 42400 → 42500 done, saved to embeddings_batches\embeddings_42400_42500.pkl
# ✅ Batch 42500 → 42600 done, saved to embeddings_batches\embeddings_42500_42600.pkl
# ✅ Batch 42600 → 42700 done, saved to embeddings_batches\embeddings_42600_42700.pkl
# ✅ Batch 42700 → 42800 done, saved to embeddings_batches\embeddings_42700_42800.pkl
# ✅ Batch 42800 → 42900 done, saved to embeddings_batches\embeddings_42800_42900.pkl
# ✅ Batch 42900 → 43000 done, saved to embeddings_batches\embeddings_42900_43000.pkl
# ✅ Batch 43000 → 43100 done, saved to embeddings_batches\embeddings_43000_43100.pkl
# ✅ Batch 43100 → 43200 done, saved to embeddings_batches\embeddings_43100_43200.pkl
# ✅ Batch 43200 → 43300 done, saved to embeddings_batches\embeddings_43200_43300.pkl
# ✅ Batch 43300 → 43400 done, saved to embeddings_batches\embeddings_43300_43400.pkl
# ✅ Batch 43400 → 43500 done, saved to embeddings_batches\embeddings_43400_43500.pkl
# ✅ Batch 43500 → 43600 done, saved to embeddings_batches\embeddings_43500_43600.pkl
# ✅ Batch 43600 → 43700 done, saved to embeddings_batches\embeddings_43600_43700.pkl
# ✅ Batch 43700 → 43800 done, saved to embeddings_batches\embeddings_43700_43800.pkl
# ✅ Batch 43800 → 43900 done, saved to embeddings_batches\embeddings_43800_43900.pkl
# ✅ Batch 43900 → 44000 done, saved to embeddings_batches\embeddings_43900_44000.pkl
# ✅ Batch 44000 → 44100 done, saved to embeddings_batches\embeddings_44000_44100.pkl
# ✅ Batch 44100 → 44200 done, saved to embeddings_batches\embeddings_44100_44200.pkl
# ✅ Batch 44200 → 44300 done, saved to embeddings_batches\embeddings_44200_44300.pkl
# ✅ Batch 44300 → 44400 done, saved to embeddings_batches\embeddings_44300_44400.pkl
# ✅ Batch 44400 → 44500 done, saved to embeddings_batches\embeddings_44400_44500.pkl
# ✅ Batch 44500 → 44600 done, saved to embeddings_batches\embeddings_44500_44600.pkl
# ✅ Batch 44600 → 44700 done, saved to embeddings_batches\embeddings_44600_44700.pkl
# ✅ Batch 44700 → 44800 done, saved to embeddings_batches\embeddings_44700_44800.pkl
# ✅ Batch 44800 → 44900 done, saved to embeddings_batches\embeddings_44800_44900.pkl
# ✅ Batch 44900 → 45000 done, saved to embeddings_batches\embeddings_44900_45000.pkl
# ✅ Batch 45000 → 45100 done, saved to embeddings_batches\embeddings_45000_45100.pkl
# ✅ Batch 45100 → 45200 done, saved to embeddings_batches\embeddings_45100_45200.pkl
# ✅ Batch 45200 → 45300 done, saved to embeddings_batches\embeddings_45200_45300.pkl
# ✅ Batch 45300 → 45400 done, saved to embeddings_batches\embeddings_45300_45400.pkl
# ✅ Batch 45400 → 45500 done, saved to embeddings_batches\embeddings_45400_45500.pkl
# ✅ Batch 45500 → 45600 done, saved to embeddings_batches\embeddings_45500_45600.pkl
# ✅ Batch 45600 → 45700 done, saved to embeddings_batches\embeddings_45600_45700.pkl
# ✅ Batch 45700 → 45800 done, saved to embeddings_batches\embeddings_45700_45800.pkl
# ✅ Batch 45800 → 45900 done, saved to embeddings_batches\embeddings_45800_45900.pkl
# ✅ Batch 45900 → 46000 done, saved to embeddings_batches\embeddings_45900_46000.pkl
# ✅ Batch 46000 → 46100 done, saved to embeddings_batches\embeddings_46000_46100.pkl
# ✅ Batch 46100 → 46200 done, saved to embeddings_batches\embeddings_46100_46200.pkl
# ✅ Batch 46200 → 46300 done, saved to embeddings_batches\embeddings_46200_46300.pkl
# ✅ Batch 46300 → 46400 done, saved to embeddings_batches\embeddings_46300_46400.pkl
# ✅ Batch 46400 → 46500 done, saved to embeddings_batches\embeddings_46400_46500.pkl
# ✅ Batch 46500 → 46600 done, saved to embeddings_batches\embeddings_46500_46600.pkl
# ✅ Batch 46600 → 46700 done, saved to embeddings_batches\embeddings_46600_46700.pkl
# ✅ Batch 46700 → 46800 done, saved to embeddings_batches\embeddings_46700_46800.pkl
# ✅ Batch 46800 → 46900 done, saved to embeddings_batches\embeddings_46800_46900.pkl
# ✅ Batch 46900 → 47000 done, saved to embeddings_batches\embeddings_46900_47000.pkl
# ✅ Batch 47000 → 47100 done, saved to embeddings_batches\embeddings_47000_47100.pkl
# ✅ Batch 47100 → 47200 done, saved to embeddings_batches\embeddings_47100_47200.pkl
# ✅ Batch 47200 → 47300 done, saved to embeddings_batches\embeddings_47200_47300.pkl
# ✅ Batch 47300 → 47400 done, saved to embeddings_batches\embeddings_47300_47400.pkl
# ✅ Batch 47400 → 47500 done, saved to embeddings_batches\embeddings_47400_47500.pkl
# ✅ Batch 47500 → 47600 done, saved to embeddings_batches\embeddings_47500_47600.pkl
# ✅ Batch 47600 → 47700 done, saved to embeddings_batches\embeddings_47600_47700.pkl
# ✅ Batch 47700 → 47800 done, saved to embeddings_batches\embeddings_47700_47800.pkl
# ✅ Batch 47800 → 47900 done, saved to embeddings_batches\embeddings_47800_47900.pkl
# ✅ Batch 47900 → 48000 done, saved to embeddings_batches\embeddings_47900_48000.pkl
# ✅ Batch 48000 → 48100 done, saved to embeddings_batches\embeddings_48000_48100.pkl
# ✅ Batch 48100 → 48200 done, saved to embeddings_batches\embeddings_48100_48200.pkl
# ✅ Batch 48200 → 48300 done, saved to embeddings_batches\embeddings_48200_48300.pkl
# ✅ Batch 48300 → 48400 done, saved to embeddings_batches\embeddings_48300_48400.pkl
# ✅ Batch 48400 → 48500 done, saved to embeddings_batches\embeddings_48400_48500.pkl
# ✅ Batch 48500 → 48600 done, saved to embeddings_batches\embeddings_48500_48600.pkl
# ✅ Batch 48600 → 48700 done, saved to embeddings_batches\embeddings_48600_48700.pkl
# ✅ Batch 48700 → 48800 done, saved to embeddings_batches\embeddings_48700_48800.pkl
# ✅ Batch 48800 → 48900 done, saved to embeddings_batches\embeddings_48800_48900.pkl
# ✅ Batch 48900 → 49000 done, saved to embeddings_batches\embeddings_48900_49000.pkl
# ✅ Batch 49000 → 49100 done, saved to embeddings_batches\embeddings_49000_49100.pkl
# ✅ Batch 49100 → 49200 done, saved to embeddings_batches\embeddings_49100_49200.pkl
# ✅ Batch 49200 → 49300 done, saved to embeddings_batches\embeddings_49200_49300.pkl
# ✅ Batch 49300 → 49400 done, saved to embeddings_batches\embeddings_49300_49400.pkl
# ✅ Batch 49400 → 49500 done, saved to embeddings_batches\embeddings_49400_49500.pkl
# ✅ Batch 49500 → 49600 done, saved to embeddings_batches\embeddings_49500_49600.pkl
# ✅ Batch 49600 → 49700 done, saved to embeddings_batches\embeddings_49600_49700.pkl
# ✅ Batch 49700 → 49800 done, saved to embeddings_batches\embeddings_49700_49800.pkl
# ✅ Batch 49800 → 49900 done, saved to embeddings_batches\embeddings_49800_49900.pkl
# ✅ Batch 49900 → 50000 done, saved to embeddings_batches\embeddings_49900_50000.pkl
# ✅ Batch 50000 → 50100 done, saved to embeddings_batches\embeddings_50000_50100.pkl
# ✅ Batch 50100 → 50200 done, saved to embeddings_batches\embeddings_50100_50200.pkl
# ✅ Batch 50200 → 50300 done, saved to embeddings_batches\embeddings_50200_50300.pkl
# ✅ Batch 50300 → 50400 done, saved to embeddings_batches\embeddings_50300_50400.pkl
# ✅ Batch 50400 → 50500 done, saved to embeddings_batches\embeddings_50400_50500.pkl
# ✅ Batch 50500 → 50600 done, saved to embeddings_batches\embeddings_50500_50600.pkl
# ✅ Batch 50600 → 50700 done, saved to embeddings_batches\embeddings_50600_50700.pkl
# ✅ Batch 50700 → 50800 done, saved to embeddings_batches\embeddings_50700_50800.pkl
# ✅ Batch 50800 → 50900 done, saved to embeddings_batches\embeddings_50800_50900.pkl
# ✅ Batch 50900 → 51000 done, saved to embeddings_batches\embeddings_50900_51000.pkl
# ✅ Batch 51000 → 51100 done, saved to embeddings_batches\embeddings_51000_51100.pkl
# ✅ Batch 51100 → 51200 done, saved to embeddings_batches\embeddings_51100_51200.pkl
# ✅ Batch 51200 → 51300 done, saved to embeddings_batches\embeddings_51200_51300.pkl
# ✅ Batch 51300 → 51400 done, saved to embeddings_batches\embeddings_51300_51400.pkl
# ✅ Batch 51400 → 51500 done, saved to embeddings_batches\embeddings_51400_51500.pkl
# ✅ Batch 51500 → 51600 done, saved to embeddings_batches\embeddings_51500_51600.pkl
# ✅ Batch 51600 → 51700 done, saved to embeddings_batches\embeddings_51600_51700.pkl
# ✅ Batch 51700 → 51800 done, saved to embeddings_batches\embeddings_51700_51800.pkl
# ✅ Batch 51800 → 51900 done, saved to embeddings_batches\embeddings_51800_51900.pkl
# ✅ Batch 51900 → 52000 done, saved to embeddings_batches\embeddings_51900_52000.pkl
# ✅ Batch 52000 → 52100 done, saved to embeddings_batches\embeddings_52000_52100.pkl
# ✅ Batch 52100 → 52200 done, saved to embeddings_batches\embeddings_52100_52200.pkl
# ✅ Batch 52200 → 52300 done, saved to embeddings_batches\embeddings_52200_52300.pkl
# ✅ Batch 52300 → 52400 done, saved to embeddings_batches\embeddings_52300_52400.pkl
# ✅ Batch 52400 → 52500 done, saved to embeddings_batches\embeddings_52400_52500.pkl
# ✅ Batch 52500 → 52600 done, saved to embeddings_batches\embeddings_52500_52600.pkl
# ✅ Batch 52600 → 52700 done, saved to embeddings_batches\embeddings_52600_52700.pkl
# ✅ Batch 52700 → 52800 done, saved to embeddings_batches\embeddings_52700_52800.pkl
# ✅ Batch 52800 → 52900 done, saved to embeddings_batches\embeddings_52800_52900.pkl
# ✅ Batch 52900 → 53000 done, saved to embeddings_batches\embeddings_52900_53000.pkl
# ✅ Batch 53000 → 53100 done, saved to embeddings_batches\embeddings_53000_53100.pkl
# ✅ Batch 53100 → 53200 done, saved to embeddings_batches\embeddings_53100_53200.pkl
# ✅ Batch 53200 → 53300 done, saved to embeddings_batches\embeddings_53200_53300.pkl
# ✅ Batch 53300 → 53400 done, saved to embeddings_batches\embeddings_53300_53400.pkl
# ✅ Batch 53400 → 53500 done, saved to embeddings_batches\embeddings_53400_53500.pkl
# ✅ Batch 53500 → 53600 done, saved to embeddings_batches\embeddings_53500_53600.pkl
# ✅ Batch 53600 → 53700 done, saved to embeddings_batches\embeddings_53600_53700.pkl
# ✅ Batch 53700 → 53800 done, saved to embeddings_batches\embeddings_53700_53800.pkl
# ✅ Batch 53800 → 53900 done, saved to embeddings_batches\embeddings_53800_53900.pkl
# ✅ Batch 53900 → 54000 done, saved to embeddings_batches\embeddings_53900_54000.pkl
# ✅ Batch 54000 → 54100 done, saved to embeddings_batches\embeddings_54000_54100.pkl
# ✅ Batch 54100 → 54200 done, saved to embeddings_batches\embeddings_54100_54200.pkl
# ✅ Batch 54200 → 54300 done, saved to embeddings_batches\embeddings_54200_54300.pkl
# ✅ Batch 54300 → 54400 done, saved to embeddings_batches\embeddings_54300_54400.pkl
# ✅ Batch 54400 → 54500 done, saved to embeddings_batches\embeddings_54400_54500.pkl
# ✅ Batch 54500 → 54600 done, saved to embeddings_batches\embeddings_54500_54600.pkl
# ✅ Batch 54600 → 54700 done, saved to embeddings_batches\embeddings_54600_54700.pkl
# ✅ Batch 54700 → 54800 done, saved to embeddings_batches\embeddings_54700_54800.pkl
# ✅ Batch 54800 → 54900 done, saved to embeddings_batches\embeddings_54800_54900.pkl
# ✅ Batch 54900 → 55000 done, saved to embeddings_batches\embeddings_54900_55000.pkl
# ✅ Batch 55000 → 55100 done, saved to embeddings_batches\embeddings_55000_55100.pkl
# ✅ Batch 55100 → 55200 done, saved to embeddings_batches\embeddings_55100_55200.pkl
# ✅ Batch 55200 → 55300 done, saved to embeddings_batches\embeddings_55200_55300.pkl
# ✅ Batch 55300 → 55400 done, saved to embeddings_batches\embeddings_55300_55400.pkl
# ✅ Batch 55400 → 55500 done, saved to embeddings_batches\embeddings_55400_55500.pkl
# ✅ Batch 55500 → 55600 done, saved to embeddings_batches\embeddings_55500_55600.pkl
# ✅ Batch 55600 → 55700 done, saved to embeddings_batches\embeddings_55600_55700.pkl
# ✅ Batch 55700 → 55800 done, saved to embeddings_batches\embeddings_55700_55800.pkl
# ✅ Batch 55800 → 55900 done, saved to embeddings_batches\embeddings_55800_55900.pkl
# ✅ Batch 55900 → 56000 done, saved to embeddings_batches\embeddings_55900_56000.pkl
# ✅ Batch 56000 → 56100 done, saved to embeddings_batches\embeddings_56000_56100.pkl
# ✅ Batch 56100 → 56200 done, saved to embeddings_batches\embeddings_56100_56200.pkl
# ✅ Batch 56200 → 56300 done, saved to embeddings_batches\embeddings_56200_56300.pkl
# ✅ Batch 56300 → 56400 done, saved to embeddings_batches\embeddings_56300_56400.pkl
# ✅ Batch 56400 → 56500 done, saved to embeddings_batches\embeddings_56400_56500.pkl
# ✅ Batch 56500 → 56600 done, saved to embeddings_batches\embeddings_56500_56600.pkl
# ✅ Batch 56600 → 56700 done, saved to embeddings_batches\embeddings_56600_56700.pkl
# ✅ Batch 56700 → 56800 done, saved to embeddings_batches\embeddings_56700_56800.pkl
# ✅ Batch 56800 → 56900 done, saved to embeddings_batches\embeddings_56800_56900.pkl
# ✅ Batch 56900 → 57000 done, saved to embeddings_batches\embeddings_56900_57000.pkl
# ✅ Batch 57000 → 57100 done, saved to embeddings_batches\embeddings_57000_57100.pkl
# ✅ Batch 57100 → 57200 done, saved to embeddings_batches\embeddings_57100_57200.pkl
# ✅ Batch 57200 → 57300 done, saved to embeddings_batches\embeddings_57200_57300.pkl
# ✅ Batch 57300 → 57400 done, saved to embeddings_batches\embeddings_57300_57400.pkl
# ✅ Batch 57400 → 57500 done, saved to embeddings_batches\embeddings_57400_57500.pkl
# ✅ Batch 57500 → 57600 done, saved to embeddings_batches\embeddings_57500_57600.pkl
# ✅ Batch 57600 → 57700 done, saved to embeddings_batches\embeddings_57600_57700.pkl
# ✅ Batch 57700 → 57800 done, saved to embeddings_batches\embeddings_57700_57800.pkl
# ✅ Batch 57800 → 57900 done, saved to embeddings_batches\embeddings_57800_57900.pkl
# ✅ Batch 57900 → 58000 done, saved to embeddings_batches\embeddings_57900_58000.pkl
# ✅ Batch 58000 → 58100 done, saved to embeddings_batches\embeddings_58000_58100.pkl
# ✅ Batch 58100 → 58200 done, saved to embeddings_batches\embeddings_58100_58200.pkl
# ✅ Batch 58200 → 58300 done, saved to embeddings_batches\embeddings_58200_58300.pkl
# ...
# ✅ Batch 473300 → 473400 done, saved to embeddings_batches\embeddings_473300_473400.pkl
# ✅ Batch 473400 → 473500 done, saved to embeddings_batches\embeddings_473400_473500.pkl
# ✅ Batch 473500 → 473600 done, saved to embeddings_batches\embeddings_473500_473600.pkl
# ✅ Batch 473600 → 473700 done, saved to embeddings_batches\embeddings_473600_473700.pkl
# ✅ Batch 473700 → 473800 done, saved to embeddings_batches\embeddings_473700_473800.pkl
# ✅ Batch 473800 → 473900 done, saved to embeddings_batches\embeddings_473800_473900.pkl
# ✅ Batch 473900 → 474000 done, saved to embeddings_batches\embeddings_473900_474000.pkl
# ✅ Batch 474000 → 474100 done, saved to embeddings_batches\embeddings_474000_474100.pkl
# ✅ Batch 474100 → 474200 done, saved to embeddings_batches\embeddings_474100_474200.pkl
# ✅ Batch 474200 → 474300 done, saved to embeddings_batches\embeddings_474200_474300.pkl
# ✅ Batch 474300 → 474400 done, saved to embeddings_batches\embeddings_474300_474400.pkl
# ✅ Batch 474400 → 474500 done, saved to embeddings_batches\embeddings_474400_474500.pkl
# ✅ Batch 474500 → 474600 done, saved to embeddings_batches\embeddings_474500_474600.pkl
# ✅ Batch 474600 → 474700 done, saved to embeddings_batches\embeddings_474600_474700.pkl
# ✅ Batch 474700 → 474800 done, saved to embeddings_batches\embeddings_474700_474800.pkl
# ✅ Batch 474800 → 474900 done, saved to embeddings_batches\embeddings_474800_474900.pkl
# ✅ Batch 474900 → 475000 done, saved to embeddings_batches\embeddings_474900_475000.pkl
# ✅ Batch 475000 → 475100 done, saved to embeddings_batches\embeddings_475000_475100.pkl
# ✅ Batch 475100 → 475200 done, saved to embeddings_batches\embeddings_475100_475200.pkl
# ✅ Batch 475200 → 475300 done, saved to embeddings_batches\embeddings_475200_475300.pkl
# ✅ Batch 475300 → 475400 done, saved to embeddings_batches\embeddings_475300_475400.pkl
# ✅ Batch 475400 → 475500 done, saved to embeddings_batches\embeddings_475400_475500.pkl
# ✅ Batch 475500 → 475600 done, saved to embeddings_batches\embeddings_475500_475600.pkl
# ✅ Batch 475600 → 475700 done, saved to embeddings_batches\embeddings_475600_475700.pkl
# ✅ Batch 475700 → 475800 done, saved to embeddings_batches\embeddings_475700_475800.pkl
# ✅ Batch 475800 → 475900 done, saved to embeddings_batches\embeddings_475800_475900.pkl
# ✅ Batch 475900 → 476000 done, saved to embeddings_batches\embeddings_475900_476000.pkl
# ✅ Batch 476000 → 476100 done, saved to embeddings_batches\embeddings_476000_476100.pkl
# ✅ Batch 476100 → 476200 done, saved to embeddings_batches\embeddings_476100_476200.pkl
# ✅ Batch 476200 → 476300 done, saved to embeddings_batches\embeddings_476200_476300.pkl
# ✅ Batch 476300 → 476400 done, saved to embeddings_batches\embeddings_476300_476400.pkl
# ✅ Batch 476400 → 476500 done, saved to embeddings_batches\embeddings_476400_476500.pkl
# ✅ Batch 476500 → 476600 done, saved to embeddings_batches\embeddings_476500_476600.pkl
# ✅ Batch 476600 → 476700 done, saved to embeddings_batches\embeddings_476600_476700.pkl
# ✅ Batch 476700 → 476800 done, saved to embeddings_batches\embeddings_476700_476800.pkl
# ✅ Batch 476800 → 476900 done, saved to embeddings_batches\embeddings_476800_476900.pkl
# ✅ Batch 476900 → 477000 done, saved to embeddings_batches\embeddings_476900_477000.pkl
# ✅ Batch 477000 → 477100 done, saved to embeddings_batches\embeddings_477000_477100.pkl
# ✅ Batch 477100 → 477200 done, saved to embeddings_batches\embeddings_477100_477200.pkl
# ✅ Batch 477200 → 477300 done, saved to embeddings_batches\embeddings_477200_477300.pkl
# ✅ Batch 477300 → 477400 done, saved to embeddings_batches\embeddings_477300_477400.pkl
# ✅ Batch 477400 → 477500 done, saved to embeddings_batches\embeddings_477400_477500.pkl
# ✅ Batch 477500 → 477600 done, saved to embeddings_batches\embeddings_477500_477600.pkl
# ✅ Batch 477600 → 477700 done, saved to embeddings_batches\embeddings_477600_477700.pkl
# ✅ Batch 477700 → 477800 done, saved to embeddings_batches\embeddings_477700_477800.pkl
# ✅ Batch 477800 → 477900 done, saved to embeddings_batches\embeddings_477800_477900.pkl
# ✅ Batch 477900 → 478000 done, saved to embeddings_batches\embeddings_477900_478000.pkl
# ✅ Batch 478000 → 478100 done, saved to embeddings_batches\embeddings_478000_478100.pkl
# ✅ Batch 478100 → 478200 done, saved to embeddings_batches\embeddings_478100_478200.pkl
# ✅ Batch 478200 → 478300 done, saved to embeddings_batches\embeddings_478200_478300.pkl
# ✅ Batch 478300 → 478400 done, saved to embeddings_batches\embeddings_478300_478400.pkl
# ✅ Batch 478400 → 478500 done, saved to embeddings_batches\embeddings_478400_478500.pkl
# ✅ Batch 478500 → 478600 done, saved to embeddings_batches\embeddings_478500_478600.pkl
# ✅ Batch 478600 → 478700 done, saved to embeddings_batches\embeddings_478600_478700.pkl
# ✅ Batch 478700 → 478800 done, saved to embeddings_batches\embeddings_478700_478800.pkl
# ✅ Batch 478800 → 478900 done, saved to embeddings_batches\embeddings_478800_478900.pkl
# ✅ Batch 478900 → 479000 done, saved to embeddings_batches\embeddings_478900_479000.pkl
# ✅ Batch 479000 → 479100 done, saved to embeddings_batches\embeddings_479000_479100.pkl
# ✅ Batch 479100 → 479200 done, saved to embeddings_batches\embeddings_479100_479200.pkl
# ✅ Batch 479200 → 479300 done, saved to embeddings_batches\embeddings_479200_479300.pkl
# ✅ Batch 479300 → 479400 done, saved to embeddings_batches\embeddings_479300_479400.pkl
# ✅ Batch 479400 → 479500 done, saved to embeddings_batches\embeddings_479400_479500.pkl
# ✅ Batch 479500 → 479600 done, saved to embeddings_batches\embeddings_479500_479600.pkl
# ✅ Batch 479600 → 479700 done, saved to embeddings_batches\embeddings_479600_479700.pkl
# ✅ Batch 479700 → 479800 done, saved to embeddings_batches\embeddings_479700_479800.pkl
# ✅ Batch 479800 → 479900 done, saved to embeddings_batches\embeddings_479800_479900.pkl
# ✅ Batch 479900 → 480000 done, saved to embeddings_batches\embeddings_479900_480000.pkl
# ✅ Batch 480000 → 480100 done, saved to embeddings_batches\embeddings_480000_480100.pkl
# ✅ Batch 480100 → 480200 done, saved to embeddings_batches\embeddings_480100_480200.pkl
# ✅ Batch 480200 → 480300 done, saved to embeddings_batches\embeddings_480200_480300.pkl
# ✅ Batch 480300 → 480400 done, saved to embeddings_batches\embeddings_480300_480400.pkl
# ✅ Batch 480400 → 480500 done, saved to embeddings_batches\embeddings_480400_480500.pkl
# ✅ Batch 480500 → 480600 done, saved to embeddings_batches\embeddings_480500_480600.pkl
# ✅ Batch 480600 → 480700 done, saved to embeddings_batches\embeddings_480600_480700.pkl
# ✅ Batch 480700 → 480800 done, saved to embeddings_batches\embeddings_480700_480800.pkl
# ✅ Batch 480800 → 480900 done, saved to embeddings_batches\embeddings_480800_480900.pkl
# ✅ Batch 480900 → 481000 done, saved to embeddings_batches\embeddings_480900_481000.pkl
# ✅ Batch 481000 → 481100 done, saved to embeddings_batches\embeddings_481000_481100.pkl
# ✅ Batch 481100 → 481200 done, saved to embeddings_batches\embeddings_481100_481200.pkl
# ✅ Batch 481200 → 481300 done, saved to embeddings_batches\embeddings_481200_481300.pkl
# ✅ Batch 481300 → 481400 done, saved to embeddings_batches\embeddings_481300_481400.pkl
# ✅ Batch 481400 → 481500 done, saved to embeddings_batches\embeddings_481400_481500.pkl
# ✅ Batch 481500 → 481600 done, saved to embeddings_batches\embeddings_481500_481600.pkl
# ✅ Batch 481600 → 481700 done, saved to embeddings_batches\embeddings_481600_481700.pkl
# ✅ Batch 481700 → 481800 done, saved to embeddings_batches\embeddings_481700_481800.pkl
# ✅ Batch 481800 → 481900 done, saved to embeddings_batches\embeddings_481800_481900.pkl
# ✅ Batch 481900 → 482000 done, saved to embeddings_batches\embeddings_481900_482000.pkl
# ✅ Batch 482000 → 482100 done, saved to embeddings_batches\embeddings_482000_482100.pkl
# ✅ Batch 482100 → 482200 done, saved to embeddings_batches\embeddings_482100_482200.pkl
# ✅ Batch 482200 → 482300 done, saved to embeddings_batches\embeddings_482200_482300.pkl
# ✅ Batch 482300 → 482400 done, saved to embeddings_batches\embeddings_482300_482400.pkl
# ✅ Batch 482400 → 482500 done, saved to embeddings_batches\embeddings_482400_482500.pkl
# ✅ Batch 482500 → 482600 done, saved to embeddings_batches\embeddings_482500_482600.pkl
# ✅ Batch 482600 → 482700 done, saved to embeddings_batches\embeddings_482600_482700.pkl
# ✅ Batch 482700 → 482800 done, saved to embeddings_batches\embeddings_482700_482800.pkl
# ✅ Batch 482800 → 482900 done, saved to embeddings_batches\embeddings_482800_482900.pkl
# ✅ Batch 482900 → 483000 done, saved to embeddings_batches\embeddings_482900_483000.pkl
# ✅ Batch 483000 → 483100 done, saved to embeddings_batches\embeddings_483000_483100.pkl
# ✅ Batch 483100 → 483200 done, saved to embeddings_batches\embeddings_483100_483200.pkl
# ✅ Batch 483200 → 483300 done, saved to embeddings_batches\embeddings_483200_483300.pkl
# ✅ Batch 483300 → 483400 done, saved to embeddings_batches\embeddings_483300_483400.pkl
# ✅ Batch 483400 → 483500 done, saved to embeddings_batches\embeddings_483400_483500.pkl
# ✅ Batch 483500 → 483600 done, saved to embeddings_batches\embeddings_483500_483600.pkl
# ✅ Batch 483600 → 483700 done, saved to embeddings_batches\embeddings_483600_483700.pkl
# ✅ Batch 483700 → 483800 done, saved to embeddings_batches\embeddings_483700_483800.pkl
# ✅ Batch 483800 → 483900 done, saved to embeddings_batches\embeddings_483800_483900.pkl
# ✅ Batch 483900 → 484000 done, saved to embeddings_batches\embeddings_483900_484000.pkl
# ✅ Batch 484000 → 484100 done, saved to embeddings_batches\embeddings_484000_484100.pkl
# ✅ Batch 484100 → 484200 done, saved to embeddings_batches\embeddings_484100_484200.pkl
# ✅ Batch 484200 → 484300 done, saved to embeddings_batches\embeddings_484200_484300.pkl
# ✅ Batch 484300 → 484400 done, saved to embeddings_batches\embeddings_484300_484400.pkl
# ✅ Batch 484400 → 484500 done, saved to embeddings_batches\embeddings_484400_484500.pkl
# ✅ Batch 484500 → 484600 done, saved to embeddings_batches\embeddings_484500_484600.pkl
# ✅ Batch 484600 → 484700 done, saved to embeddings_batches\embeddings_484600_484700.pkl
# ✅ Batch 484700 → 484800 done, saved to embeddings_batches\embeddings_484700_484800.pkl
# ✅ Batch 484800 → 484900 done, saved to embeddings_batches\embeddings_484800_484900.pkl
# ✅ Batch 484900 → 485000 done, saved to embeddings_batches\embeddings_484900_485000.pkl
# ✅ Batch 485000 → 485100 done, saved to embeddings_batches\embeddings_485000_485100.pkl
# ✅ Batch 485100 → 485200 done, saved to embeddings_batches\embeddings_485100_485200.pkl
# ✅ Batch 485200 → 485300 done, saved to embeddings_batches\embeddings_485200_485300.pkl
# ✅ Batch 485300 → 485400 done, saved to embeddings_batches\embeddings_485300_485400.pkl
# ✅ Batch 485400 → 485500 done, saved to embeddings_batches\embeddings_485400_485500.pkl
# ✅ Batch 485500 → 485600 done, saved to embeddings_batches\embeddings_485500_485600.pkl
# ✅ Batch 485600 → 485700 done, saved to embeddings_batches\embeddings_485600_485700.pkl
# ✅ Batch 485700 → 485800 done, saved to embeddings_batches\embeddings_485700_485800.pkl
# ✅ Batch 485800 → 485900 done, saved to embeddings_batches\embeddings_485800_485900.pkl
# ✅ Batch 485900 → 486000 done, saved to embeddings_batches\embeddings_485900_486000.pkl
# ✅ Batch 486000 → 486100 done, saved to embeddings_batches\embeddings_486000_486100.pkl
# ✅ Batch 486100 → 486200 done, saved to embeddings_batches\embeddings_486100_486200.pkl
# ✅ Batch 486200 → 486300 done, saved to embeddings_batches\embeddings_486200_486300.pkl
# ✅ Batch 486300 → 486400 done, saved to embeddings_batches\embeddings_486300_486400.pkl
# ✅ Batch 486400 → 486500 done, saved to embeddings_batches\embeddings_486400_486500.pkl
# ✅ Batch 486500 → 486600 done, saved to embeddings_batches\embeddings_486500_486600.pkl
# ✅ Batch 486600 → 486700 done, saved to embeddings_batches\embeddings_486600_486700.pkl
# ✅ Batch 486700 → 486800 done, saved to embeddings_batches\embeddings_486700_486800.pkl
# ✅ Batch 486800 → 486900 done, saved to embeddings_batches\embeddings_486800_486900.pkl
# ✅ Batch 486900 → 487000 done, saved to embeddings_batches\embeddings_486900_487000.pkl
# ✅ Batch 487000 → 487100 done, saved to embeddings_batches\embeddings_487000_487100.pkl
# ✅ Batch 487100 → 487200 done, saved to embeddings_batches\embeddings_487100_487200.pkl
# ✅ Batch 487200 → 487300 done, saved to embeddings_batches\embeddings_487200_487300.pkl
# ✅ Batch 487300 → 487400 done, saved to embeddings_batches\embeddings_487300_487400.pkl
# ✅ Batch 487400 → 487500 done, saved to embeddings_batches\embeddings_487400_487500.pkl
# ✅ Batch 487500 → 487600 done, saved to embeddings_batches\embeddings_487500_487600.pkl
# ✅ Batch 487600 → 487700 done, saved to embeddings_batches\embeddings_487600_487700.pkl
# ✅ Batch 487700 → 487800 done, saved to embeddings_batches\embeddings_487700_487800.pkl
# ✅ Batch 487800 → 487900 done, saved to embeddings_batches\embeddings_487800_487900.pkl
# ✅ Batch 487900 → 488000 done, saved to embeddings_batches\embeddings_487900_488000.pkl
# ✅ Batch 488000 → 488100 done, saved to embeddings_batches\embeddings_488000_488100.pkl
# ✅ Batch 488100 → 488200 done, saved to embeddings_batches\embeddings_488100_488200.pkl
# ✅ Batch 488200 → 488300 done, saved to embeddings_batches\embeddings_488200_488300.pkl
# ✅ Batch 488300 → 488400 done, saved to embeddings_batches\embeddings_488300_488400.pkl
# ✅ Batch 488400 → 488500 done, saved to embeddings_batches\embeddings_488400_488500.pkl
# ✅ Batch 488500 → 488600 done, saved to embeddings_batches\embeddings_488500_488600.pkl
# ✅ Batch 488600 → 488700 done, saved to embeddings_batches\embeddings_488600_488700.pkl
# ✅ Batch 488700 → 488800 done, saved to embeddings_batches\embeddings_488700_488800.pkl
# ✅ Batch 488800 → 488900 done, saved to embeddings_batches\embeddings_488800_488900.pkl
# ✅ Batch 488900 → 489000 done, saved to embeddings_batches\embeddings_488900_489000.pkl
# ✅ Batch 489000 → 489100 done, saved to embeddings_batches\embeddings_489000_489100.pkl
# ✅ Batch 489100 → 489200 done, saved to embeddings_batches\embeddings_489100_489200.pkl
# ✅ Batch 489200 → 489300 done, saved to embeddings_batches\embeddings_489200_489300.pkl
# ✅ Batch 489300 → 489400 done, saved to embeddings_batches\embeddings_489300_489400.pkl
# ✅ Batch 489400 → 489500 done, saved to embeddings_batches\embeddings_489400_489500.pkl
# ✅ Batch 489500 → 489600 done, saved to embeddings_batches\embeddings_489500_489600.pkl
# ✅ Batch 489600 → 489700 done, saved to embeddings_batches\embeddings_489600_489700.pkl
# ✅ Batch 489700 → 489800 done, saved to embeddings_batches\embeddings_489700_489800.pkl
# ✅ Batch 489800 → 489900 done, saved to embeddings_batches\embeddings_489800_489900.pkl
# ✅ Batch 489900 → 490000 done, saved to embeddings_batches\embeddings_489900_490000.pkl
# ✅ Batch 490000 → 490100 done, saved to embeddings_batches\embeddings_490000_490100.pkl
# ✅ Batch 490100 → 490200 done, saved to embeddings_batches\embeddings_490100_490200.pkl
# ✅ Batch 490200 → 490300 done, saved to embeddings_batches\embeddings_490200_490300.pkl
# ✅ Batch 490300 → 490400 done, saved to embeddings_batches\embeddings_490300_490400.pkl
# ✅ Batch 490400 → 490500 done, saved to embeddings_batches\embeddings_490400_490500.pkl
# ✅ Batch 490500 → 490600 done, saved to embeddings_batches\embeddings_490500_490600.pkl
# ✅ Batch 490600 → 490700 done, saved to embeddings_batches\embeddings_490600_490700.pkl
# ✅ Batch 490700 → 490800 done, saved to embeddings_batches\embeddings_490700_490800.pkl
# ✅ Batch 490800 → 490900 done, saved to embeddings_batches\embeddings_490800_490900.pkl
# ✅ Batch 490900 → 491000 done, saved to embeddings_batches\embeddings_490900_491000.pkl
# ✅ Batch 491000 → 491100 done, saved to embeddings_batches\embeddings_491000_491100.pkl
# ✅ Batch 491100 → 491200 done, saved to embeddings_batches\embeddings_491100_491200.pkl
# ✅ Batch 491200 → 491300 done, saved to embeddings_batches\embeddings_491200_491300.pkl
# ✅ Batch 491300 → 491400 done, saved to embeddings_batches\embeddings_491300_491400.pkl
# ✅ Batch 491400 → 491500 done, saved to embeddings_batches\embeddings_491400_491500.pkl
# ✅ Batch 491500 → 491593 done, saved to embeddings_batches\embeddings_491500_491593.pkl
# ✅ Finished embedding all recipes.

# %%
import pickle
from langchain_community.vectorstores import Chroma
import os
import chromadb

persist_directory = "chroma_recipes"
os.makedirs(persist_directory, exist_ok=True)

# Initialize persistent Chroma client
client = chromadb.PersistentClient(path=persist_directory)
collection = client.create_collection("recipes", embedding_function=None)

# Load batch files
batch_files = sorted(os.listdir("embeddings_batches"))

for batch_idx, file in enumerate(batch_files):
    if not file.endswith(".pkl"):
        continue
    with open(os.path.join("embeddings_batches", file), "rb") as f:
        embeddings = pickle.load(f)  # list of embeddings

    # Create fake IDs and dummy texts (if you want to store texts too, load them from embedding_text.txt)
    batch_size = len(embeddings)
    texts = [f"recipe_{batch_idx}_{i}" for i in range(batch_size)]
    ids = [f"{batch_idx}_{i}" for i in range(batch_size)]

    # Add embeddings
    collection.add(
        documents=texts,
        embeddings=embeddings,
        ids=ids
    )

    print(f"✅ Batch {batch_idx} added to Chroma")

print("✅ All embeddings inserted into Chroma!")
# Out:
# ✅ Batch 0 added to Chroma
# ✅ Batch 1 added to Chroma
# ✅ Batch 2 added to Chroma
# ✅ Batch 3 added to Chroma
# ✅ Batch 4 added to Chroma
# ✅ Batch 5 added to Chroma
# ✅ Batch 6 added to Chroma
# ✅ Batch 7 added to Chroma
# ✅ Batch 8 added to Chroma
# ✅ Batch 9 added to Chroma
# ✅ Batch 10 added to Chroma
# ✅ Batch 11 added to Chroma
# ✅ Batch 12 added to Chroma
# ✅ Batch 13 added to Chroma
# ✅ Batch 14 added to Chroma
# ✅ Batch 15 added to Chroma
# ✅ Batch 16 added to Chroma
# ✅ Batch 17 added to Chroma
# ✅ Batch 18 added to Chroma
# ✅ Batch 19 added to Chroma
# ✅ Batch 20 added to Chroma
# ✅ Batch 21 added to Chroma
# ✅ Batch 22 added to Chroma
# ✅ Batch 23 added to Chroma
# ✅ Batch 24 added to Chroma
# ✅ Batch 25 added to Chroma
# ✅ Batch 26 added to Chroma
# ✅ Batch 27 added to Chroma
# ✅ Batch 28 added to Chroma
# ✅ Batch 29 added to Chroma
# ✅ Batch 30 added to Chroma
# ✅ Batch 31 added to Chroma
# ✅ Batch 32 added to Chroma
# ✅ Batch 33 added to Chroma
# ✅ Batch 34 added to Chroma
# ✅ Batch 35 added to Chroma
# ✅ Batch 36 added to Chroma
# ✅ Batch 37 added to Chroma
# ✅ Batch 38 added to Chroma
# ✅ Batch 39 added to Chroma
# ✅ Batch 40 added to Chroma
# ✅ Batch 41 added to Chroma
# ✅ Batch 42 added to Chroma
# ✅ Batch 43 added to Chroma
# ✅ Batch 44 added to Chroma
# ✅ Batch 45 added to Chroma
# ✅ Batch 46 added to Chroma
# ✅ Batch 47 added to Chroma
# ✅ Batch 48 added to Chroma
# ✅ Batch 49 added to Chroma
# ✅ Batch 50 added to Chroma
# ✅ Batch 51 added to Chroma
# ✅ Batch 52 added to Chroma
# ✅ Batch 53 added to Chroma
# ✅ Batch 54 added to Chroma
# ✅ Batch 55 added to Chroma
# ✅ Batch 56 added to Chroma
# ✅ Batch 57 added to Chroma
# ✅ Batch 58 added to Chroma
# ✅ Batch 59 added to Chroma
# ✅ Batch 60 added to Chroma
# ✅ Batch 61 added to Chroma
# ✅ Batch 62 added to Chroma
# ✅ Batch 63 added to Chroma
# ✅ Batch 64 added to Chroma
# ✅ Batch 743 added to Chroma
# ✅ Batch 744 added to Chroma
# ✅ Batch 745 added to Chroma
# ✅ Batch 746 added to Chroma
# ✅ Batch 747 added to Chroma
# ✅ Batch 748 added to Chroma
# ✅ Batch 749 added to Chroma
# ✅ Batch 750 added to Chroma
# ✅ Batch 751 added to Chroma
# ✅ Batch 752 added to Chroma
# ✅ Batch 753 added to Chroma
# ✅ Batch 754 added to Chroma
# ✅ Batch 755 added to Chroma
# ✅ Batch 756 added to Chroma
# ✅ Batch 757 added to Chroma
# ✅ Batch 758 added to Chroma
# ✅ Batch 759 added to Chroma
# ✅ Batch 760 added to Chroma
# ✅ Batch 761 added to Chroma
# ✅ Batch 762 added to Chroma
# ✅ Batch 763 added to Chroma
# ✅ Batch 764 added to Chroma
# ✅ Batch 765 added to Chroma
# ✅ Batch 766 added to Chroma
# ✅ Batch 767 added to Chroma
# ✅ Batch 768 added to Chroma
# ✅ Batch 769 added to Chroma
# ✅ Batch 770 added to Chroma
# ✅ Batch 771 added to Chroma
# ✅ Batch 772 added to Chroma
# ✅ Batch 773 added to Chroma
# ✅ Batch 774 added to Chroma
# ✅ Batch 775 added to Chroma
# ✅ Batch 776 added to Chroma
# ✅ Batch 777 added to Chroma
# ✅ Batch 778 added to Chroma
# ✅ Batch 779 added to Chroma
# ✅ Batch 780 added to Chroma
# ✅ Batch 781 added to Chroma
# ✅ Batch 782 added to Chroma
# ✅ Batch 783 added to Chroma
# ✅ Batch 784 added to Chroma
# ✅ Batch 785 added to Chroma
# ✅ Batch 786 added to Chroma
# ✅ Batch 787 added to Chroma
# ✅ Batch 788 added to Chroma
# ✅ Batch 789 added to Chroma
# ✅ Batch 790 added to Chroma
# ✅ Batch 791 added to Chroma
# ✅ Batch 792 added to Chroma
# ✅ Batch 793 added to Chroma
# ✅ Batch 794 added to Chroma
# ✅ Batch 795 added to Chroma
# ✅ Batch 796 added to Chroma
# ✅ Batch 797 added to Chroma
# ✅ Batch 798 added to Chroma
# ✅ Batch 799 added to Chroma
# ✅ Batch 800 added to Chroma
# ✅ Batch 801 added to Chroma
# ✅ Batch 802 added to Chroma
# ✅ Batch 803 added to Chroma
# ✅ Batch 804 added to Chroma
# ✅ Batch 805 added to Chroma
# ✅ Batch 806 added to Chroma
# ✅ Batch 807 added to Chroma
# ✅ Batch 808 added to Chroma
# ✅ Batch 809 added to Chroma
# ✅ Batch 810 added to Chroma
# ✅ Batch 811 added to Chroma
# ✅ Batch 812 added to Chroma
# ✅ Batch 813 added to Chroma
# ✅ Batch 814 added to Chroma
# ✅ Batch 815 added to Chroma
# ✅ Batch 816 added to Chroma
# ✅ Batch 817 added to Chroma
# ✅ Batch 818 added to Chroma
# ✅ Batch 819 added to Chroma
# ✅ Batch 820 added to Chroma
# ✅ Batch 821 added to Chroma
# ✅ Batch 822 added to Chroma
# ✅ Batch 823 added to Chroma
# ✅ Batch 824 added to Chroma
# ✅ Batch 825 added to Chroma
# ✅ Batch 826 added to Chroma
# ✅ Batch 827 added to Chroma
